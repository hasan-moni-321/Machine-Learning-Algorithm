# %%
from IPython.display import Image

# %%
#cost function of Linear Regression Algorithm
Image(filename=('/home/hasan/Pictures/a1.png'))

# %%
#Formula of best fit line
Image(filename=('/home/hasan/Pictures/a2.png'))

# %%
# Gradient Descent of Linear Regression
Image(filename=('/home/hasan/Pictures/a3.png'))

# %%
#convergence theorem
Image(filename=('/home/hasan/Pictures/a4.png'))

# %% [markdown]
# We need to take alpha value very small. because we need to reach into global minimum point gradually.
