# %%
from IPython.display import Image

# %%
#Formula of best fit line
Image(filename=('/home/hasan/Pictures/a2.png'))

# %%
# Gradient Descent of Ridge Regression
Image(filename=('/home/hasan/Pictures/a3.png'))

# %%
#convergence theorem
Image(filename=('/home/hasan/Pictures/a11.png'))

# %% [markdown]
# In Lasso cost function we need to add(lambda*abs(slope)). That is the main difference between linear regression cost function and lasso regression cost function.
#
# Note:
#     lambda value range is between 0-posivitve number

# %%
#convergence theorem
Image(filename=('/home/hasan/Pictures/a4.png'))
